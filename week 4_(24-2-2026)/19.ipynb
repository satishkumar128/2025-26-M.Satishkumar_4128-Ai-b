# %% [markdown]
# <a href="https://colab.research.google.com/github/satishkumar128/2025-26-M.Satishkumar_4128-Ai-b/blob/main/week%204_(24-2-2026)/19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data cleaning operations
import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)
print("First 5 rows of dataset:\n")
print(df.head())
print("\nMissing values (True means missing):\n")
print(df.isnull())
print("\nTotal missing values in each column:\n")
print(df.isnull().sum())
df_cleaned = df.fillna(df.mean(numeric_only=True))
print("\nDataset after replacing missing values with column mean:\n")
print(df_cleaned.head())
# Out:
# First 5 rows of dataset:
#
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Missing values (True means missing):
#
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# ...
