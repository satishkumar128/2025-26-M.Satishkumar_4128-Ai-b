# %% [markdown]
# <a href="https://colab.research.google.com/github/satishkumar128/2025-26-M.Satishkumar_4128-Ai-b/blob/main/dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating Dictionaries
d1 = {'a': 1, 'b': 2}
d2 = dict(c=3, d=4)
print("d1:", d1)
print("d2:", d2)
# Out:
# d1: {'a': 1, 'b': 2}
# d2: {'c': 3, 'd': 4}
