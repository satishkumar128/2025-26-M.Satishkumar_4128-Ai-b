# %% [markdown]
# <a href="https://colab.research.google.com/github/satishkumar128/satishkumar_4128-Ai-b/blob/main/tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cration of tuples
t1 = (1, 2, 3)
t2 = (3, 4, 5)
t3 = (5,)

# %%
print(t1)
# Out:
# (1, 2, 3)

# %%
print(t2)
print(t3)
# Out:
# (3, 4, 5)
# (5,)

# %%
#indexing
t2[1]
# Out:
# 4

# %%
#slicing
t = (1, 2, 3, 4, 5)
t[1:4]
# Out:
# (2, 3, 4)

# %%
t = (1, 2, 3, 4, 5)

t[:3]
# Out:
# (1, 2, 3)

# %%
#repeatation
t1 * 3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)
