# %% [markdown]
# <a href="https://colab.research.google.com/github/satishkumar128/2025-26-M.Satishkumar_4128-Ai-b/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sets
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1)
# Out:
# {1, 2, 3}

# %%
s1.add(4)
s1.update([5, 6])
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
len(s1)
print(len(s1))
# Out:
# 6

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}

total = sum(s1) + sum(s2)
print(total)
# Out:
# 18
