# %% [markdown]
# <a href="https://colab.research.google.com/github/satishkumar128/2025-26-M.Satishkumar_4128-Ai-b/blob/main/week_6/24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
url="https://raw.githubusercontent.com/selva86/datasets/master/Advertising.csv"
df=pd.read_csv(url)
X=df[["TV"]]
Y=df["sales"]
model=LinearRegression()
model.fit(X,Y)
print("Intercept:", model.intercept_)
print("slope:", model.coef_)
df["predicted_sales"]=model.predict(X)
print(df.head())
# Out:
# Intercept: 7.032593549127695
# slope: [0.04753664]
#    Unnamed: 0     TV  radio  newspaper  sales  predicted_sales
# 0           1  230.1   37.8       69.2   22.1        17.970775
# 1           2   44.5   39.3       45.1   10.4         9.147974
# 2           3   17.2   45.9       69.3    9.3         7.850224
# 3           4  151.5   41.3       58.5   18.5        14.234395
# 4           5  180.8   10.8       58.4   12.9        15.627218
